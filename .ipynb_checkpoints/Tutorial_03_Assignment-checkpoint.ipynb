# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !wget -O dataset.csv https://docs.google.com/spreadsheets/d/1lS9HEz8FreAkCpR_w_ykAHy3oWeQBqiuc_RJyr3dfbE/export?format=csv&gid=1322780754
# Out:
# --2024-08-24 06:14:55--  https://docs.google.com/spreadsheets/d/1lS9HEz8FreAkCpR_w_ykAHy3oWeQBqiuc_RJyr3dfbE/export?format=csv
# Resolving docs.google.com (docs.google.com)... 172.217.204.113, 172.217.204.101, 172.217.204.139, ...
# Connecting to docs.google.com (docs.google.com)|172.217.204.113|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://doc-08-1k-sheets.googleusercontent.com/export/54bogvaave6cua4cdnls17ksc4/hchr1es18fpjqapbkvhb6f8dso/1724480095000/100752720053680324863/*/1lS9HEz8FreAkCpR_w_ykAHy3oWeQBqiuc_RJyr3dfbE?format=csv [following]
# Warning: wildcards not supported in HTTP.
# --2024-08-24 06:14:55--  https://doc-08-1k-sheets.googleusercontent.com/export/54bogvaave6cua4cdnls17ksc4/hchr1es18fpjqapbkvhb6f8dso/1724480095000/100752720053680324863/*/1lS9HEz8FreAkCpR_w_ykAHy3oWeQBqiuc_RJyr3dfbE?format=csv
# Resolving doc-08-1k-sheets.googleusercontent.com (doc-08-1k-sheets.googleusercontent.com)... 142.251.107.132, 2607:f8b0:400c:c32::84
# Connecting to doc-08-1k-sheets.googleusercontent.com (doc-08-1k-sheets.googleusercontent.com)|142.251.107.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/csv]
# Saving to: ‘dataset.csv’
#
# dataset.csv             [   <=>              ]   6.53M  14.0MB/s    in 0.5s
#
# 2024-08-24 06:14:57 (14.0 MB/s) - ‘dataset.csv’ saved [6850374]

# %%
file_path = '/content/dataset.csv'
df = pd.read_csv(file_path)
# Out:
# <ipython-input-23-9adb4d9a2db1>:2: DtypeWarning: Columns (9,14,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)

# %%
df
# Out:
#         Museum ID                                        Museum Name  \
# 0      8400200098                    ALASKA AVIATION HERITAGE MUSEUM
# 1      8400200117                            ALASKA BOTANICAL GARDEN
# 2      8400200153  ALASKA CHALLENGER CENTER FOR SPACE SCIENCE TEC...
# 3      8400200143                ALASKA EDUCATORS HISTORICAL SOCIETY
# 4      8400200027                             ALASKA HERITAGE MUSEUM
# ...           ...                                                ...
# 33067  8405600184                   WYOMING STATE HISTORICAL SOCIETY
# 33068  8405600061                               WYOMING STATE MUSEUM
# 33069  8405600158      WYOMING TERRITORIAL PARK HISTORIC ASSOCIATION
# 33070  8405600137                      WYOMING TRANSPORTATION MUSEUM
# 33071  8405600199                          YELLOWSTONE NATIONAL PARK
#
#                                               Legal Name Alternate Name  \
# 0                        ALASKA AVIATION HERITAGE MUSEUM            NaN
# 1                            ALASKA BOTANICAL GARDEN INC            NaN
# 2      ALASKA CHALLENGER CENTER FOR SPACE SCIENCE TEC...            NaN
# 3                    ALASKA EDUCATORS HISTORICAL SOCIETY            NaN
# 4                        ALASKA AVIATION HERITAGE MUSEUM            NaN
# ...                                                  ...            ...
# 33067                   WYOMING STATE HISTORICAL SOCIETY            NaN
# 33068                WYOMING STATE MUSEUM VOLUNTEERS INC            NaN
# 33069  WYOMING TERRITORIAL PARK HISTORIC ASSOCIATION INC            NaN
# 33070                 WYOMING TRANSPORTATION MUSEUM CORP            NaN
# 33071                  LITTLE PEOPLE LEARNING CENTER INC            NaN
#
#                                          Museum Type Institution Name  \
# 0                                     HISTORY MUSEUM              NaN
# 1      ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER              NaN
# 2         SCIENCE & TECHNOLOGY MUSEUM OR PLANETARIUM              NaN
# 3                              HISTORIC PRESERVATION              NaN
# 4                                     HISTORY MUSEUM              NaN
# ...                                              ...              ...
# 33067                          HISTORIC PRESERVATION              NaN
# 33068                                 GENERAL MUSEUM              NaN
# 33069                          HISTORIC PRESERVATION              NaN
# 33070                                 HISTORY MUSEUM              NaN
# 33071                          HISTORIC PRESERVATION              NaN
#
#       Street Address (Administrative Location) City (Administrative Location)  \
# 0                             4721 AIRCRAFT DR                      ANCHORAGE
# 1                    4601 CAMPBELL AIRSTRIP RD                      ANCHORAGE
# 2                          9711 KENAI SPUR HWY                          KENAI
# 3                             214 BIRCH STREET                          KENAI
# 4                   301 W NORTHERN LIGHTS BLVD                      ANCHORAGE
# ...                                        ...                            ...
# 33067                                PO BOX 73                       SHERIDAN
# 33068                      2301 CENTRAL AVENUE                       CHEYENNE
# 33069                   1273 N 15TH ST STE 121                        LARAMIE
# 33070                               PO BOX 704                       CHEYENNE
# 33071                    NATIONAL PARK SERVICE      YELLOWSTONE NATIONAL PARK
#
#       State (Administrative Location) Zip Code (Administrative Location)  ...  \
# 0                                  AK                              99502  ...
# 1                                  AK                              99507  ...
# 2                                  AK                              99611  ...
# 3                                  AK                              99611  ...
# 4                                  AK                              99503  ...
# ...                               ...                                ...  ...
# 33067                              WY                              82801  ...
# 33068                              WY                              82001  ...
# 33069                              WY                              82072  ...
# 33070                              WY                              82003  ...
# 33071                              WY                              82190  ...
#
#        Latitude  Longitude Locale Code (NCES)  County Code (FIPS)  \
# 0      61.17925 -149.97254                1.0                20.0
# 1      61.16890 -149.76708                4.0                20.0
# 2      60.56149 -151.21598                3.0               122.0
# 3      60.56280 -151.26597                3.0               122.0
# 4      61.17925 -149.97254                1.0                20.0
# ...         ...        ...                ...                 ...
# 33067  44.82345 -106.87592                4.0                33.0
# 33068  41.13941 -104.81813                1.0                21.0
# 33069  41.32276 -105.57686                3.0                 1.0
# 33070  41.13010 -104.81916                1.0                21.0
# 33071  44.91303 -110.41584                4.0                29.0
#
#       State Code (FIPS)  Region Code (AAM)  Employer ID Number  Tax Period  \
# 0                   2.0                  6           920071852    201312.0
# 1                   2.0                  6           920115504    201312.0
# 2                   2.0                  6           921761906    201312.0
# 3                   2.0                  6           920165178    201412.0
# 4                   2.0                  6           920071852    201312.0
# ...                 ...                ...                 ...         ...
# 33067              56.0                  5         836007540.0         NaN
# 33068              56.0                  5         237368629.0    201404.0
# 33069              56.0                  5         830318392.0    201312.0
# 33070              56.0                  5         830295570.0    201309.0
# 33071              56.0                  5         830249072.0    201312.0
#
#           Income    Revenue
# 0       602912.0   550236.0
# 1      1379576.0  1323742.0
# 2       740030.0   729080.0
# 3            0.0        0.0
# 4       602912.0   550236.0
# ...          ...        ...
# 33067        NaN        NaN
# 33068        0.0        0.0
# 33069   208508.0    83981.0
# 33070        0.0        0.0
# 33071   127496.0   126762.0
#
# [33072 rows x 25 columns]

# %% [markdown]
# # EDA
#
# Code up the following concepts with regards to EDA.
#
# *   Correlation
# *   Mean, median, mode
# In addition, write down inferences from the dataset.

# %%
# Correlation

# %%
# Mean, median and mode

# %% [markdown]
# ### Inferences from the dataset
#
# *
# *
# *
# *

# %% [markdown]
# # Preprocessing
# Code up the following concepts with regards to Preprocessing. Justify the reason for using them for this specific dataset
#
# *   Filling in missing values.
# *   Encoding
#
# Any other techniques that you might need, please justify their usage and code them up.

# %%
# Filling in missing values

# %%
# Encoding
# Hint: Figure out which columns need to be encoded. Would One-Hot Encoding be enough for handling this type of data? What are the alternatives?

# %%
# Any other preprocessing...?

# %%
# Final dataset
# Out:
#         Museum ID                                        Museum Name  \
# 0      8400200098                    ALASKA AVIATION HERITAGE MUSEUM
# 1      8400200117                            ALASKA BOTANICAL GARDEN
# 2      8400200153  ALASKA CHALLENGER CENTER FOR SPACE SCIENCE TEC...
# 3      8400200143                ALASKA EDUCATORS HISTORICAL SOCIETY
# 4      8400200027                             ALASKA HERITAGE MUSEUM
# ...           ...                                                ...
# 33067  8405600184                   WYOMING STATE HISTORICAL SOCIETY
# 33068  8405600061                               WYOMING STATE MUSEUM
# 33069  8405600158      WYOMING TERRITORIAL PARK HISTORIC ASSOCIATION
# 33070  8405600137                      WYOMING TRANSPORTATION MUSEUM
# 33071  8405600199                          YELLOWSTONE NATIONAL PARK
#
#                                               Legal Name Alternate Name  \
# 0                        ALASKA AVIATION HERITAGE MUSEUM            NaN
# 1                            ALASKA BOTANICAL GARDEN INC            NaN
# 2      ALASKA CHALLENGER CENTER FOR SPACE SCIENCE TEC...            NaN
# 3                    ALASKA EDUCATORS HISTORICAL SOCIETY            NaN
# 4                        ALASKA AVIATION HERITAGE MUSEUM            NaN
# ...                                                  ...            ...
# 33067                   WYOMING STATE HISTORICAL SOCIETY            NaN
# 33068                WYOMING STATE MUSEUM VOLUNTEERS INC            NaN
# 33069  WYOMING TERRITORIAL PARK HISTORIC ASSOCIATION INC            NaN
# 33070                 WYOMING TRANSPORTATION MUSEUM CORP            NaN
# 33071                  LITTLE PEOPLE LEARNING CENTER INC            NaN
#
#                                          Museum Type Institution Name  \
# 0                                     HISTORY MUSEUM              NaN
# 1      ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER              NaN
# 2         SCIENCE & TECHNOLOGY MUSEUM OR PLANETARIUM              NaN
# 3                              HISTORIC PRESERVATION              NaN
# 4                                     HISTORY MUSEUM              NaN
# ...                                              ...              ...
# 33067                          HISTORIC PRESERVATION              NaN
# 33068                                 GENERAL MUSEUM              NaN
# 33069                          HISTORIC PRESERVATION              NaN
# 33070                                 HISTORY MUSEUM              NaN
# 33071                          HISTORIC PRESERVATION              NaN
#
#       Street Address (Administrative Location)  \
# 0                             4721 AIRCRAFT DR
# 1                    4601 CAMPBELL AIRSTRIP RD
# 2                          9711 KENAI SPUR HWY
# 3                             214 BIRCH STREET
# 4                   301 W NORTHERN LIGHTS BLVD
# ...                                        ...
# 33067                                PO BOX 73
# 33068                      2301 CENTRAL AVENUE
# 33069                   1273 N 15TH ST STE 121
# 33070                               PO BOX 704
# 33071                    NATIONAL PARK SERVICE
#
#        City (Administrative Location)  State (Administrative Location)  \
# 0                                 153                                0
# 1                                 153                                0
# 2                                3809                                0
# 3                                3809                                0
# 4                                 153                                0
# ...                               ...                              ...
# 33067                            7003                               50
# 33068                            1323                               50
# 33069                            4101                               50
# 33070                            1323                               50
# 33071                            8575                               50
#
#       Zip Code (Administrative Location)  ...  Latitude  Longitude  \
# 0                                  99502  ...  61.17925 -149.97254
# 1                                  99507  ...  61.16890 -149.76708
# 2                                  99611  ...  60.56149 -151.21598
# 3                                  99611  ...  60.56280 -151.26597
# 4                                  99503  ...  61.17925 -149.97254
# ...                                  ...  ...       ...        ...
# 33067                              82801  ...  44.82345 -106.87592
# 33068                              82001  ...  41.13941 -104.81813
# 33069                              82072  ...  41.32276 -105.57686
# 33070                              82003  ...  41.13010 -104.81916
# 33071                              82190  ...  44.91303 -110.41584
#
#       Locale Code (NCES)  County Code (FIPS) State Code (FIPS)  \
# 0                    1.0                20.0               2.0
# 1                    4.0                20.0               2.0
# 2                    3.0               122.0               2.0
# 3                    3.0               122.0               2.0
# 4                    1.0                20.0               2.0
# ...                  ...                 ...               ...
# 33067                4.0                33.0              56.0
# 33068                1.0                21.0              56.0
# 33069                3.0                 1.0              56.0
# 33070                1.0                21.0              56.0
# 33071                4.0                29.0              56.0
#
#        Region Code (AAM)  Employer ID Number     Tax Period        Income  \
# 0                      6           920071852  201312.000000  6.029120e+05
# 1                      6           920115504  201312.000000  1.379576e+06
# 2                      6           921761906  201312.000000  7.400300e+05
# 3                      6           920165178  201412.000000  0.000000e+00
# 4                      6           920071852  201312.000000  6.029120e+05
# ...                  ...                 ...            ...           ...
# 33067                  5         836007540.0  201347.458548  1.069682e+08
# 33068                  5         237368629.0  201404.000000  0.000000e+00
# 33069                  5         830318392.0  201312.000000  2.085080e+05
# 33070                  5         830295570.0  201309.000000  0.000000e+00
# 33071                  5         830249072.0  201312.000000  1.274960e+05
#
#             Revenue
# 0      5.502360e+05
# 1      1.323742e+06
# 2      7.290800e+05
# 3      0.000000e+00
# 4      5.502360e+05
# ...             ...
# 33067  2.097605e+07
# 33068  0.000000e+00
# 33069  8.398100e+04
# 33070  0.000000e+00
# 33071  1.267620e+05
#
# [33072 rows x 25 columns]
